# %%
import tensorflow as tf
import collections
import random
from PIL import Image
# Out:
# /home/root/.pyenv/versions/3.6.12/lib/python3.6/site-packages/pandas/compat/__init__.py:120: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
import json

# %%
annotation_file="../data/external/rehe-2.json"

# %%
with open(annotation_file, 'r') as f:
    annotations = json.load(f)

# %%
image_path_to_caption = collections.defaultdict(list)
for val in annotations['images']:
  #caption = f"<start> {val['file_name']} <end>"
  image_path = '../data' + '/raw/' + val['file_name']
  image_path_to_caption[image_path].append(image_path)

image_paths = list(image_path_to_caption.keys())
random.shuffle(image_paths)
print(image_paths[2])
# Out:
# ../data/raw/IMAG0078.JPG

# %%
Image.open(image_paths[2])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=4000x3000 at 0x7F8B1AFD3C88>

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-322804cd0e0e> in <module>
# ----> 1 print(PIL.__version__)
#
# NameError: name 'PIL' is not defined

# %%
image_paths = list(image_path_to_caption.keys())
random.shuffle(image_paths)

# Select the first 6000 image_paths from the shuffled set.
# Approximately each image id has 5 captions associated with it, so that will 
# lead to 30,000 examples.
train_image_paths = image_paths[:6000]
print(len(train_image_paths))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-8d9d0ec09d33> in <module>
# ----> 1 image_paths = list(image_path_to_caption.keys())
#       2 random.shuffle(image_paths)
#       3
#       4 # Select the first 6000 image_paths from the shuffled set.
#       5 # Approximately each image id has 5 captions associated with it, so that will
#
# NameError: name 'image_path_to_caption' is not defined

# %%
img_name_vector = []

for image_path in train_image_paths:
  caption_list = image_path_to_caption[image_path]
  train_captions.extend(caption_list)
  img_name_vector.extend([image_path] * len(caption_list))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-18c6752c7589> in <module>
#       1 img_name_vector = []
#       2
# ----> 3 for image_path in train_image_paths:
#       4   caption_list = image_path_to_caption[image_path]
#       5   train_captions.extend(caption_list)
#
# NameError: name 'train_image_paths' is not defined

# %%
print(train_captions[0])
Image.open(img_name_vector[0])
