# %%
import dvc.api

# %%
dvc.api.get_url(path= "reh/IMAG0001.JPG", repo="myminio", remote = "myminio")
# Out:
# ---------------------------------------------------------------------------
# GitCommandError                           Traceback (most recent call last)
# ~/.pyenv/versions/3.6.12/lib/python3.6/site-packages/dvc/scm/git/__init__.py in clone(url, to_path, rev, shallow_branch)
#     141                 if shallow_branch is None:
# --> 142                     tmp_repo = clone_from()
#     143                 else:
#
# ~/.pyenv/versions/3.6.12/lib/python3.6/site-packages/git/repo/base.py in clone_from(cls, url, to_path, progress, env, multi_options, **kwargs)
#    1031             git.update_environment(**env)
# -> 1032         return cls._clone(git, url, to_path, GitCmdObjectDB, progress, multi_options, **kwargs)
#    1033
#
# ~/.pyenv/versions/3.6.12/lib/python3.6/site-packages/git/repo/base.py in _clone(cls, git, url, path, odb_default_type, progress, multi_options, **kwargs)
#     968         if progress:
# ...
